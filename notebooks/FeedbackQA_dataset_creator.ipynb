# %%
from src.utils import generate_content_id

# %%
from datasets import load_dataset
import pandas as pd

data_files = {
    "train": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_train.json",
    "validation": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_valid.json",
    "test": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_test.json"
}

ds = load_dataset("json", data_files=data_files)
ratings = pd.DataFrame(ds["train"])


# ratings = load_dataset("McGill-NLP/feedbackQA")["train"]
# ratings = pd.DataFrame(ratings)

ratings["review_1"] = ratings["rating"].apply(lambda x: x[0])
ratings["explanation_1"] = ratings["feedback"].apply(lambda x: x[0])
ratings["review_2"] = ratings["rating"].apply(lambda x: x[1])
ratings["explanation_2"] = ratings["feedback"].apply(lambda x: x[1])
# ratings = ratings.drop(columns=["feedback"])

# Map scores to numeric values
conversion_dict = {"Excellent": 4, "Acceptable": 3,
                   "Could be Improved": 2, "Bad": 1}
ratings["score_1"] = ratings["review_1"].map(conversion_dict)
ratings["score_2"] = ratings["review_2"].map(conversion_dict)


ratings['answer'] = ratings['passage'].apply(
    lambda x: x['reference']['section_content'])

id_columns = ['question', 'answer']
# ratings['input_id'] = ratings.apply(lambda row: generate_content_id(row, id_columns), axis=1)

ratings.groupby("score_1").first()
# Out:
#                                                   question  \
# score_1
# 1                         How do I get help finding a job?
# 2        If I am in Australia on a worker holiday marke...
# 3        Do immigration detention centers have proper PPE?
# 4                         How do I get help finding a job?
#
#                                                    passage  \
# score_1
# 1        {'passage_id': 126, 'reference': {'page_title'...
# 2        {'passage_id': 581, 'reference': {'page_title'...
# 3        {'passage_id': 220, 'reference': {'page_title'...
# 4        {'passage_id': 140, 'reference': {'page_title'...
#
#                                                   feedback  \
# score_1
# 1        [Talks about tax credits for businesses that h...
# 2        [Answer is about Working Holiday Makers, but d...
# 3        [Claims it monitors PPE levels in the immigran...
# 4        [Has a link to detailed information about gove...
#
#                                   rating     domain           review_1  \
# score_1
# 1                      [Bad, Acceptable]  Australia                Bad
# 2        [Could be Improved, Acceptable]  Australia  Could be Improved
# 3               [Acceptable, Acceptable]  Australia         Acceptable
# 4         [Excellent, Could be Improved]  Australia          Excellent
#
#                                              explanation_1           review_2  \
# score_1
# 1        Talks about tax credits for businesses that hi...         Acceptable
# 2        Answer is about Working Holiday Makers, but do...         Acceptable
# 3        Claims it monitors PPE levels in the immigrant...         Acceptable
# 4        Has a link to detailed information about gover...  Could be Improved
#
#                                              explanation_2  score_2  \
# score_1
# 1        This answer discusses the Employment Fund, whi...        3
# 2        Answer is rather cut and dry but is also a lit...        3
# 3        This gives a general answer to the question bu...        3
# 4        This answer provides a link for job searches, ...        2
#
#                                                     answer
# score_1
# 1        To further assist job seekers to prepare for a...
# 2        No. Existing arrangements for specified work w...
# 3        PPE levels are being closely monitored to ensu...
# 4        If you are a current job seeker or participant...

# %%
# ratings[['question', 'answer', 'review_1', 'explanation_1', 'review_2',
#          'explanation_2']][:500].to_csv('FeedbackQA_ratings_500.csv')

# %%
from datasets import load_dataset
import pandas as pd

data_files = {
    "train": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_train.json",
    "validation": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_valid.json",
    "test": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_test.json"
}

ds = load_dataset("json", data_files=data_files)
ratings = pd.DataFrame(ds[["train"]])


# ratings = load_dataset("McGill-NLP/feedbackQA")["train"]
# ratings = pd.DataFrame(ratings)

ratings["review_1"] = ratings["rating"].apply(lambda x: x[0])
ratings["explanation_1"] = ratings["feedback"].apply(lambda x: x[0])
ratings["review_2"] = ratings["rating"].apply(lambda x: x[1])
ratings["explanation_2"] = ratings["feedback"].apply(lambda x: x[1])
# ratings = ratings.drop(columns=["feedback"])

# Map scores to numeric values
conversion_dict = {"Excellent": 4, "Acceptable": 3,
                   "Could be Improved": 2, "Bad": 1}
ratings["score_1"] = ratings["review_1"].map(conversion_dict)
ratings["score_2"] = ratings["review_2"].map(conversion_dict)


ratings['answer'] = ratings['passage'].apply(
    lambda x: x['reference']['section_content'])

id_columns = ['question', 'answer']
# ratings['input_id'] = ratings.apply(lambda row: generate_content_id(row, id_columns), axis=1)

ratings.groupby("score_1").first()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 11
#       4 data_files = {
#       5     "train": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_train.json",
#       6     "validation": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_valid.json",
#       7     "test": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_test.json"
#       8 }
#      10 ds = load_dataset("json", data_files=data_files)
# ---> 11 ratings = pd.DataFrame(ds[["train", "validation", "test"]])
#      14 # ratings = load_dataset("McGill-NLP/feedbackQA")["train"]
#      15 # ratings = pd.DataFrame(ratings)
#      17 ratings["review_1"] = ratings["rating"].apply(lambda x: x[0])
#
# File c:\Users\Wouter Barter\Documents\AI_thesis\venv312\Lib\site-packages\datasets\dataset_dict.py:92, in DatasetDict.__getitem__(self, k)
#      88 available_suggested_splits = [
#      89     split for split in (Split.TRAIN, Split.TEST, Split.VALIDATION) if split in self
#      90 ]
#      91 suggested_split = available_suggested_splits[0] if available_suggested_splits else list(self)[0]
# ---> 92 raise KeyError(
#      93     f"Invalid key: {k}. Please first select a split. For example: "
#      94     f"`my_dataset_dictionary['{suggested_split}'][{k}]`. "
#      95     f"Available splits: {sorted(self)}"
#      96 )
#
# KeyError: "Invalid key: ['train', 'validation', 'test']. Please first select a split. For example: `my_dataset_dictionary['train'][['train', 'validation', 'test']]`. Available splits: ['test', 'train', 'validation']"

# %% [markdown]
# # Load

# %%
from datasets import load_dataset
import pandas as pd
from src import paths
from src.utils import generate_content_id

# %%
data_files = {
    "train": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_train.json",
    "validation": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_valid.json",
    "test": "https://huggingface.co/datasets/McGill-NLP/feedbackQA/resolve/main/data/feedback_test.json"
}

ds = load_dataset("json", data_files=data_files)
df_train = pd.DataFrame(ds["train"])
df_train['source_file'] = 'train'
df_validation = pd.DataFrame(ds["validation"])
df_validation['source_file'] = 'validation'
df_test = pd.DataFrame(ds["test"])
df_test['source_file'] = 'test'

ratings = pd.concat([df_train, df_validation, df_test])

ratings.to_parquet(paths.RAW_DATA_DIR / 'MCGILL_FEEDBACKQA_V2.parquet')


ratings
# Out:
#                                                question  \
# 0                      How do I get help finding a job?
# 1                      How do I get help finding a job?
# 2                      How do I get help finding a job?
# 3     If I am in Australia on a worker holiday marke...
# 4     If I am in Australia on a worker holiday marke...
# ...                                                 ...
# 1990  How can I access contraception during the COVI...
# 1991    Is it ok to change my contraception method now?
# 1992  Is it a requirement for suspected or confirmed...
# 1993  How can food producers make sure the water the...
# 1994  Why do we need to stay active during lockdown ...
#
#                                                 passage  \
# 0     {'passage_id': 140, 'reference': {'page_title'...
# 1     {'passage_id': 139, 'reference': {'page_title'...
# 2     {'passage_id': 126, 'reference': {'page_title'...
# 3     {'passage_id': 581, 'reference': {'page_title'...
# 4     {'passage_id': 577, 'reference': {'page_title'...
# ...                                                 ...
# 1990  {'passage_id': 72, 'reference': {'page_title':...
# 1991  {'passage_id': 72, 'reference': {'page_title':...
# 1992  {'passage_id': 105, 'reference': {'page_title'...
# 1993  {'passage_id': 209, 'reference': {'page_title'...
# 1994  {'passage_id': 44, 'reference': {'page_title':...
#
#                                                feedback  \
# 0     [Has a link to detailed information about gove...
# 1     [A link to a job search website is included, a...
# 2     [Talks about tax credits for businesses that h...
# 3     [Answer is about Working Holiday Makers, but d...
# 4     [Discusses pandemic visas. Doesn't mention the...
# ...                                                 ...
# 1990  [This talks about access to contraceptives but...
# 1991  [This answer relates to the question and thus ...
# 1992  [This answer does not relate to the original q...
# 1993  [There is not a lot of information in this ans...
# 1994  [This is a direct answer to the question. this...
#
#                                                  rating     domain source_file
# 0                        [Excellent, Could be Improved]  Australia       train
# 1                                [Excellent, Excellent]  Australia       train
# 2                                     [Bad, Acceptable]  Australia       train
# 3                       [Could be Improved, Acceptable]  Australia       train
# 4                              [Bad, Could be Improved]  Australia       train
# ...                                                 ...        ...         ...
# 1990                      [Could be Improved, Bad, Bad]        WHO        test
# 1991         [Excellent, Could be Improved, Acceptable]        WHO        test
# 1992                                    [Bad, Bad, Bad]        WHO        test
# 1993  [Could be Improved, Could be Improved, Accepta...        WHO        test
# 1994                [Excellent, Could be Improved, Bad]        WHO        test
#
# [9065 rows x 6 columns]

# %% [markdown]
# # Processing

# %%
ratings = pd.read_parquet(paths.RAW_DATA_DIR / 'MCGILL_FEEDBACKQA_V2.parquet')

ratings["review_1"] = ratings["rating"].apply(lambda x: x[0])
ratings["explanation_1"] = ratings["feedback"].apply(lambda x: x[0])
ratings["review_2"] = ratings["rating"].apply(lambda x: x[1])
ratings["explanation_2"] = ratings["feedback"].apply(lambda x: x[1])
# ratings = ratings.drop(columns=["feedback"])

# Map scores to numeric values
conversion_dict = {"Excellent": 4, "Acceptable": 3,
                   "Could be Improved": 2, "Bad": 1}
ratings["score_1"] = ratings["review_1"].map(conversion_dict)
ratings["score_2"] = ratings["review_2"].map(conversion_dict)


ratings['answer'] = ratings['passage'].apply(
    lambda x: x['reference']['section_content'])

ratings['input_id'] = ratings.apply(
    lambda row: generate_content_id(row, id_columns), axis=1)

# %%
ratings.to_parquet(paths.PROCESSED_DATA_DIR / "MCGILL_FEEDBACKQA_V2.parquet")
