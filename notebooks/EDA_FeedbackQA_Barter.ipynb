# %%
import torch
from pathlib import Path
from src.prompt_manager import PromptManager

from src.data_manager import DataManager
from src import data_processing
import pandas as pd

# %%
df_qa = pd.read_parquet('../data/raw/MCGILL_QA_FEEDBACK.parquet')
df_qa['token_count'] = (df_qa['question'] +" "+ df_qa['answer']).str.split().str.len()


df_deals = pd.read_parquet('../data/raw/BARTER_DEALS.parquet')
df_deals['token_count'] = df_deals.deal_text.str.split().str.len()

dfs = [df_qa, df_deals]

# %% [markdown]
# # McGill FeedbackQA

# %% [markdown]
# ## Features

# %% [markdown]
# - disagreement

# %%
qa_relevant_columns = ['question', 'answer', 'rating', 'explanation_1', 'explanation_2', 'human_disagreement']

df_qa['human_disagreement'] = abs(df_qa.score_1 - df_qa.score_2)
df_qa.human_disagreement.value_counts()
# Out:
# human_disagreement
# 0    2701
# 1    1896
# 2     756
# 3     307
# Name: count, dtype: int64

# %% [markdown]
# - Question frequency
#     - Some questions are asked twice, e.g. see figure 1, where the question on respiratory shortages is posed twice with both a bad and a good answer. This would make for an interesting comparison. We see that each question is asked at least twice.

# %%
df_qa['question_count'] = df_qa.groupby('question')['question'].transform('count')
df_qa['question_disagreement'] = df_qa.groupby('question')['human_disagreement'].transform('sum')
df_qa['question'].value_counts()
# Out:
# question
# Is it safe for me to manually replace my IUD at home?                                                                              3
# How do I get help finding a job?                                                                                                   3
# If I am in Australia on a worker holiday marker visa, can I apply for a second visa because I work in a critical COVID-19 area?    3
# Do immigration detention centers have proper PPE?                                                                                  3
# information for job seekers  during the COVID-19 outbreak                                                                          3
#                                                                                                                                   ..
# What do Family Day Care service providers need to know when their educators don't have an ABN?                                     3
# Who can provide telehealth services and how do they bill for their services during the Coronavirus outbreak?                       3
# What should I know before I apply for superannuation?                                                                              3
# What are the support services available during this pandemic?                                                                      3
# Will children have access to meals while school is out?                                                                            2
# Name: count, Length: 1887, dtype: int64

# %% [markdown]
# ## Analysis

# %%
large_disagreement = df_qa[df_qa.human_disagreement == 3]
large_disagreement_clean = large_disagreement[qa_relevant_columns]
large_disagreement_clean
# Out:
#                                                question  \
# 31    Is it still possible to access medical appoint...
# 35    what qualifies one to go into quarantine  duri...
# 99              Can I still have my clinical education?
# 141   Does there exist any visa to support people wh...
# 158   What should household members and caregivers d...
# ...                                                 ...
# 5641  What are the different ways through which I ca...
# 5645  Are tuberculosis testing supplies disrupted by...
# 5646  Are tuberculosis testing supplies disrupted by...
# 5654            Can you explain to me what self-care is
# 5656            Can you explain to me what self-care is
#
#                                                  answer                rating  \
# 31    If you are struggling to breathe or seriously ...  ['Excellent', 'Bad']
# 35    Quarantine is when you are well but may have b...  ['Excellent', 'Bad']
# 99    As health service providers respond to the COV...  ['Excellent', 'Bad']
# 141   If you have evidence from your employer that y...  ['Excellent', 'Bad']
# 158   You should only share a house with a person wi...  ['Bad', 'Excellent']
# ...                                                 ...                   ...
# 5641  There is currently no evidence that people can...  ['Excellent', 'Bad']
# 5645  Appropriate planning and monitoring are essent...  ['Bad', 'Excellent']
# 5646  The diagnostic methods for tuberculosis (TB) a...  ['Excellent', 'Bad']
# 5654  Self-care interventions recommended by WHO are...  ['Excellent', 'Bad']
# 5656  With the major disruptions to the normal funct...  ['Excellent', 'Bad']
#
#                                           explanation_1  \
# 31    Explains the different ways doctors may handle...
# 35    Brief but clear explanation of when people nee...
# 99    Says that some student educational programs ha...
# 141   It provides helpful information on what needs ...
# 158   Answer refers to people who are staying with s...
# ...                                                 ...
# 5641  Describes how conronavirus does and does not s...
# 5645  This answer does not provide any information o...
# 5646  This answer addresses the fact that the two te...
# 5654  This answer does a decent job at explaining wh...
# 5656  This answer talks about what self care is and ...
#
#                                           explanation_2  human_disagreement
# 31    This answer relates to emergency situations an...                   3
# 35    This does not answer the question. This answer...                   3
# 99    This answer does not relate to clinical educat...                   3
# 141   This does not answer the question. This inform...                   3
# 158   Has clear information about what steps people ...                   3
# ...                                                 ...                 ...
# 5641  This answer does not relate to other ways that...                   3
# 5645  This answer talks about the supply of TB tests...                   3
# 5646  This answer does not provide any information o...                   3
# 5654  This answer is irrelevant to the question. Thi...                   3
# 5656  This does not answer the question. This answer...                   3
#
# [307 rows x 6 columns]

# %%
no_disagreement = df_qa[df_qa.human_disagreement == 0]
no_disagreement_clean = no_disagreement[qa_relevant_columns]
no_disagreement_clean
# Out:
#                                                question  \
# 1                      How do I get help finding a job?
# 5     If I am in Australia on a worker holiday marke...
# 6     Do immigration detention centers have proper PPE?
# 7     Do immigration detention centers have proper PPE?
# 8     Do immigration detention centers have proper PPE?
# ...                                                 ...
# 5652  How can practioners provide services to chroni...
# 5655            Can you explain to me what self-care is
# 5657  Is it safe for me to manually replace my IUD a...
# 5658  Is it safe for me to manually replace my IUD a...
# 5659  Is it safe for me to manually replace my IUD a...
#
#                                                  answer  \
# 1     In this rapidly changing jobs market the Austr...
# 5     You can apply for a further WHM visa if you ha...
# 6     If clinically indicated detainees will be test...
# 7     It has been observed that most religious group...
# 8     PPE levels are being closely monitored to ensu...
# ...                                                 ...
# 5652  It is important to assure continuous access to...
# 5655  WHO’s definition of self care is the ability o...
# 5657  If you do not want to become pregnant, you sho...
# 5658  No. Disposable medical face masks are intended...
# 5659  Removal of long acting methods such as implant...
#
#                             rating  \
# 1       ['Excellent', 'Excellent']
# 5       ['Excellent', 'Excellent']
# 6                   ['Bad', 'Bad']
# 7                   ['Bad', 'Bad']
# 8     ['Acceptable', 'Acceptable']
# ...                            ...
# 5652    ['Excellent', 'Excellent']
# 5655    ['Excellent', 'Excellent']
# 5657                ['Bad', 'Bad']
# 5658                ['Bad', 'Bad']
# 5659    ['Excellent', 'Excellent']
#
#                                           explanation_1  \
# 1     A link to a job search website is included, as...
# 5     Answer instructs the requester to apply for a ...
# 6     Does not address the matter at issue in the qu...
# 7     Does not address the matter at issue in the qu...
# 8     Claims it monitors PPE levels in the immigrant...
# ...                                                 ...
# 5652  Has detailed information about providing servi...
# 5655   This answer explains what self care is directly.
# 5657  Does not address whether or not replacing an I...
# 5658  Does not answer whether or not IUD can be safe...
# 5659  Answers whether or not an IUD can be removed s...
#
#                                           explanation_2  human_disagreement
# 1     Includes a link to a Jobs Hub page, which is b...                   0
# 5     Has a detailed description of the circumstance...                   0
# 6     The question is about the availability of PPE ...                   0
# 7     The question is about prevalence of PPE in det...                   0
# 8     This gives a general answer to the question bu...                   0
# ...                                                 ...                 ...
# 5652  This answer gives a lot of information.  The i...                   0
# 5655  This is a direct answer to the question. This ...                   0
# 5657  The answer is irrelevant to the question. This...                   0
# 5658  This answer is irrelevant to the question. Thi...                   0
# 5659  This information answers the question directly...                   0
#
# [2701 rows x 6 columns]

# %%
df_qa['token_count'].describe()
# Out:
# count    5660.000000
# mean      166.071731
# std       143.826120
# min         6.000000
# 25%        80.000000
# 50%       124.000000
# 75%       200.000000
# max      2306.000000
# Name: token_count, dtype: float64

# %%
df_qa[df_qa['question'] == "Is it still possible to access medical appointments and medications through my doctor"][qa_relevant_columns]
# Out:
#                                              question  \
# 30  Is it still possible to access medical appoint...
# 31  Is it still possible to access medical appoint...
# 32  Is it still possible to access medical appoint...
#
#                                                answer  \
# 30  For more information for patients on accessing...
# 31  If you are struggling to breathe or seriously ...
# 32  You can access bulk-billed appointments with y...
#
#                           rating  \
# 30  ['Acceptable', 'Acceptable']
# 31          ['Excellent', 'Bad']
# 32   ['Excellent', 'Acceptable']
#
#                                         explanation_1  \
# 30  Doesn't say whether you can set up medical app...
# 31  Explains the different ways doctors may handle...
# 32  Gives information on how patients can access a...
#
#                                         explanation_2  human_disagreement
# 30  This answer, while related to the question, gi...                   0
# 31  This answer relates to emergency situations an...                   3
# 32  This answer relates to accessing medical appoi...                   1

# %%
df_qa
# Out:
#       Unnamed: 0                                           question  \
# 0              0                   How do I get help finding a job?
# 1              1                   How do I get help finding a job?
# 2              2                   How do I get help finding a job?
# 3              3  If I am in Australia on a worker holiday marke...
# 4              4  If I am in Australia on a worker holiday marke...
# ...          ...                                                ...
# 5655        5655            Can you explain to me what self-care is
# 5656        5656            Can you explain to me what self-care is
# 5657        5657  Is it safe for me to manually replace my IUD a...
# 5658        5658  Is it safe for me to manually replace my IUD a...
# 5659        5659  Is it safe for me to manually replace my IUD a...
#
#                                                 passage  \
# 0     {'passage_id': 140, 'reference': {'page_title'...
# 1     {'passage_id': 139, 'reference': {'page_title'...
# 2     {'passage_id': 126, 'reference': {'page_title'...
# 3     {'passage_id': 581, 'reference': {'page_title'...
# 4     {'passage_id': 577, 'reference': {'page_title'...
# ...                                                 ...
# 5655  {'passage_id': 159, 'reference': {'page_title'...
# 5656  {'passage_id': 158, 'reference': {'page_title'...
# 5657  {'passage_id': 70, 'reference': {'page_title':...
# 5658  {'passage_id': 103, 'reference': {'page_title'...
# 5659  {'passage_id': 67, 'reference': {'page_title':...
#
#                                                feedback  \
# 0     ['Has a link to detailed information about gov...
# 1     ['A link to a job search website is included, ...
# 2     ['Talks about tax credits for businesses that ...
# 3     ["Answer is about Working Holiday Makers, but ...
# 4     ["Discusses pandemic visas. Doesn't mention th...
# ...                                                 ...
# 5655  ['This answer explains what self care is direc...
# 5656  ["This answer talks about what self care is an...
# 5657  ['Does not address whether or not replacing an...
# 5658  ['Does not answer whether or not IUD can be sa...
# 5659  ['Answers whether or not an IUD can be removed...
#
#                                    rating     domain           review_1  \
# 0      ['Excellent', 'Could be Improved']  Australia          Excellent
# 1              ['Excellent', 'Excellent']  Australia          Excellent
# 2                   ['Bad', 'Acceptable']  Australia                Bad
# 3     ['Could be Improved', 'Acceptable']  Australia  Could be Improved
# 4            ['Bad', 'Could be Improved']  Australia                Bad
# ...                                   ...        ...                ...
# 5655           ['Excellent', 'Excellent']        WHO          Excellent
# 5656                 ['Excellent', 'Bad']        WHO          Excellent
# 5657                       ['Bad', 'Bad']        WHO                Bad
# 5658                       ['Bad', 'Bad']        WHO                Bad
# 5659           ['Excellent', 'Excellent']        WHO          Excellent
#
#                                           explanation_1           review_2  \
# 0     Has a link to detailed information about gover...  Could be Improved
# 1     A link to a job search website is included, as...          Excellent
# 2     Talks about tax credits for businesses that hi...         Acceptable
# 3     Answer is about Working Holiday Makers, but do...         Acceptable
# 4     Discusses pandemic visas. Doesn't mention the ...  Could be Improved
# ...                                                 ...                ...
# 5655   This answer explains what self care is directly.          Excellent
# 5656  This answer talks about what self care is and ...                Bad
# 5657  Does not address whether or not replacing an I...                Bad
# 5658  Does not answer whether or not IUD can be safe...                Bad
# 5659  Answers whether or not an IUD can be removed s...          Excellent
#
#                                           explanation_2  score_1  score_2  \
# 0     This answer provides a link for job searches, ...        4        2
# 1     Includes a link to a Jobs Hub page, which is b...        4        4
# 2     This answer discusses the Employment Fund, whi...        1        3
# 3     Answer is rather cut and dry but is also a lit...        2        3
# 4     This answer is very vague and does not answer ...        1        2
# ...                                                 ...      ...      ...
# 5655  This is a direct answer to the question. This ...        4        4
# 5656  This does not answer the question. This answer...        4        1
# 5657  The answer is irrelevant to the question. This...        1        1
# 5658  This answer is irrelevant to the question. Thi...        1        1
# 5659  This information answers the question directly...        4        4
#
#                                                  answer          input_id  \
# 0     If you are a current job seeker or participant...  eff9e000675931f5
# 1     In this rapidly changing jobs market the Austr...  c8be913323f10444
# 2     To further assist job seekers to prepare for a...  31effc925bc04105
# 3     No. Existing arrangements for specified work w...  610d0764ed04054d
# 4     The COVID-19 Pandemic event visa can only be g...  033e9fcef5d75297
# ...                                                 ...               ...
# 5655  WHO’s definition of self care is the ability o...  87acd0f1a053ee69
# 5656  With the major disruptions to the normal funct...  77641257547b9e1a
# 5657  If you do not want to become pregnant, you sho...  16b4ea5c8b2b6721
# 5658  No. Disposable medical face masks are intended...  f2610cfa76f5bbde
# 5659  Removal of long acting methods such as implant...  20afb8d5047a8040
#
#       token_count  human_disagreement  question_count  question_disagreement
# 0             153                   2               3                      4
# 1              88                   0               3                      4
# 2             103                   2               3                      4
# 3             180                   1               3                      2
# 4              39                   1               3                      2
# ...           ...                 ...             ...                    ...
# 5655           44                   0               3                      6
# 5656           94                   3               3                      6
# 5657           84                   0               3                      0
# 5658           81                   0               3                      0
# 5659          158                   0               3                      0
#
# [5660 rows x 18 columns]

# %% [markdown]
# # Barter Deals

# %%
df_deals['token_count'].describe()
# Out:
# count    5111.000000
# mean       79.271180
# std        73.645539
# min         0.000000
# 25%        32.500000
# 50%        59.000000
# 75%       105.000000
# max       886.000000
# Name: token_count, dtype: float64

# %% [markdown]
# ## Company popularity analysis

# %% [markdown]
# Findings:
# - Some partners that post multiple successful deals are active users of the platform, and obtain many applications
#     - There is likely a relationship between "platform activity" and "deal success". This leads to simultaneity:
#         - We predict applicants using marketing copy quality. Companies that experience success on the platform will post more deals of higher quality (since they will be more motivated to do so by their success).
#             - -> High application deals will automatically have better copy quality, because the locations were better to begin with.
#     - We solve this with the Mundlak decomposition by accounting for the unobserved Location effect and modeling the within-company effect
# - Some partners post deals in multiple categories, which we can subdivide by using location_id

# %%
a = df_deals.groupby('partner_id')['applicants_applications_count'].sum().sort_values(ascending=False)[:20]

# %%
top_10_companies = df_deals[df_deals['partner_id'].isin(a.index)]
top_10_companies['company_total_apps'] = top_10_companies.groupby('partner_id')['applicants_applications_count'].transform("sum")
top_10_companies
# Out:
# C:\Users\Wouter Barter\AppData\Local\Temp\ipykernel_16224\1548907598.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_companies['company_total_apps'] = top_10_companies.groupby('partner_id')['applicants_applications_count'].transform("sum")
#       applicants_applications_count  \
# 0                                39
# 2                                23
# 5                                73
# 12                                0
# 52                                0
# ...                             ...
# 4964                              9
# 4974                             12
# 5032                             36
# 5099                             74
# 5100                             96
#
#                                           content_types  \
# 0     [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 2     [{'id': 29, 'name': 'UGC', 'slug': 'Film-Strip'}]
# 5     [{'id': 31, 'name': 'Lifestyle', 'slug': 'Mart...
# 12    [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 52    [{'id': 39, 'name': 'Experiences', 'slug': 'Te...
# ...                                                 ...
# 4964        [{'id': 35, 'name': 'Mom', 'slug': 'Baby'}]
# 4974  [{'id': 29, 'name': 'UGC', 'slug': 'Film-Strip...
# 5032  [{'id': 29, 'name': 'UGC', 'slug': 'Film-Strip...
# 5099  [{'id': 39, 'name': 'Experiences', 'slug': 'Te...
# 5100  [{'id': 29, 'name': 'UGC', 'slug': 'Film-Strip...
#
#                                    deal_id  \
# 0     0196edc7-e6a8-00c8-6ff5-ea60fa3f2895
# 2     019689e2-bfb5-00c8-6485-23352d64b0e5
# 5     019689e2-efa8-00c8-0aff-9b643cb6337b
# 12    01985615-068a-00c8-502e-689ad4f46f4f
# 52    019689e4-3a57-00c8-7868-45557942d2d8
# ...                                    ...
# 4964  01989848-a2ce-00c8-23e3-c6768bcb7246
# 4974  019689e2-d0fe-00c8-59e6-903960feec2b
# 5032  019702fb-c43e-00c8-952c-9fab143a893f
# 5099  01985afa-00dd-00c8-9469-b4e1d4090baf
# 5100  01987a95-6826-00c8-efdd-31cda2f64f0b
#
#                                              main_image  \
# 0     uploads/deals/0196edc7-5969-ffff-6700-7ae699b8...
# 2     uploads/deals/019689e2-c06c-ffff-baf0-c7e9decd...
# 5     uploads/deals/019689e2-f073-ffff-29f7-5fc60421...
# 12    uploads/deals/01985615-0778-ffff-5f39-475ebacc...
# 52    uploads/deals/019689e4-3af8-ffff-5d5b-d3e82ea9...
# ...                                                 ...
# 4964  uploads/deals/01989848-6fe4-ffff-12d8-4b5eeba6...
# 4974  uploads/deals/019689e2-d21d-ffff-6b5b-b1d9c169...
# 5032  uploads/deals/019702fb-4778-ffff-63d6-1893bce7...
# 5099  uploads/deals/01985af9-a0f9-ffff-39de-179c9d4a...
# 5100  uploads/deals/01987a87-f480-ffff-f7b6-1046a545...
#
#       min_social_media_followers deal_tags                 live_since  \
# 0                           2500      None 2025-05-20 15:21:28.249567
# 2                           5000      None 2025-03-04 11:46:18.176627
# 5                           5000      None 2025-03-05 12:10:51.501958
# 12                          1500      None                        NaT
# 52                          2500      None                        NaT
# ...                          ...       ...                        ...
# 4964                        2500      None 2025-08-11 08:39:14.081970
# 4974                        2500      None 2025-04-07 11:09:44.777404
# 5032                        1500      None 2025-05-24 15:49:03.852349
# 5099                        1500      None 2025-07-30 10:56:30.624179
# 5100                        2500      None 2025-08-05 14:14:28.797885
#
#                      created_at                 updated_at  \
# 0    2025-05-20 13:00:23.080212 2025-10-28 10:55:34.719187
# 2    2025-03-04 11:46:18.176627 2025-05-01 03:27:41.316646
# 5    2025-03-05 12:10:51.501958 2025-05-01 03:27:53.621989
# 12   2025-07-29 12:07:55.274571 2025-07-29 12:08:05.638372
# 52   2023-10-17 16:28:45.927833 2025-05-01 03:29:18.311782
# ...                         ...                        ...
# 4964 2025-08-11 08:39:13.872022 2025-08-11 08:39:14.114160
# 4974 2025-04-07 11:09:44.777404 2025-10-08 07:50:50.593540
# 5032 2025-05-24 15:49:03.678463 2025-05-24 15:49:03.872785
# 5099 2025-07-30 10:56:30.429868 2025-08-18 18:02:35.564690
# 5100 2025-08-05 14:14:28.646272 2025-08-05 14:14:28.797960
#
#                            deleted_at  ... gender  featured_image  \
# 0                                 NaT  ...   None            None
# 2                                 NaT  ...   None            None
# 5                                 NaT  ...   None            None
# 12                                NaT  ...   None            None
# 52   2024-05-31 08:26:35.053459+00:00  ...   None            None
# ...                               ...  ...    ...             ...
# 4964                              NaT  ...   None            None
# 4974                              NaT  ...   None            None
# 5032                              NaT  ...   None            None
# 5099                              NaT  ...   None            None
# 5100                              NaT  ...   None            None
#
#                                 company_id test_nr_of_apps update_at_date  \
# 0     0199f1d4-b501-015e-5c45-1bc8300b3949              39     2025-10-28
# 2                                     None              23     2025-05-01
# 5                                     None              73     2025-05-01
# 12                                    None               0     2025-07-29
# 52                                    None               0     2025-05-01
# ...                                    ...             ...            ...
# 4964                                  None               9     2025-08-11
# 4974                                  None              12     2025-10-08
# 5032                                  None              36     2025-05-24
# 5099                                  None              74     2025-08-18
# 5100                                  None              96     2025-08-05
#
#      diff apps_after_7_days  apps_after_7_days_OLD token_count  \
# 0       0                39                   39.0         107
# 2       0                13                   13.0          63
# 5       0                33                   33.0          64
# 12      0                 0                    NaN           3
# 52      0                 0                    NaN          32
# ...   ...               ...                    ...         ...
# 4964    0                 8                    3.0         134
# 4974    0                 3                    0.0          52
# 5032    0                10                   20.0          22
# 5099    0                53                   53.0         164
# 5100    0                67                   67.0         150
#
#      company_total_apps
# 0                  3706
# 2                  1160
# 5                  1160
# 12                 3706
# 52                 3706
# ...                 ...
# 4964               1473
# 4974               1473
# 5032               1473
# 5099               2748
# 5100               1237
#
# [368 rows x 42 columns]

# %%
df_deals[df_deals.partner_id == 85]
# Out:
#       applicants_applications_count  \
# 0                                39
# 12                                0
# 52                                0
# 130                              27
# 192                               5
# ...                             ...
# 4325                             43
# 4345                            109
# 4412                              6
# 4674                             18
# 4921                             34
#
#                                           content_types  \
# 0     [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 12    [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 52    [{'id': 39, 'name': 'Experiences', 'slug': 'Te...
# 130   [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 192   [{'id': 41, 'name': 'Activities', 'slug': 'per...
# ...                                                 ...
# 4325  [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 4345  [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 4412  [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 4674  [{'id': 41, 'name': 'Activities', 'slug': 'per...
# 4921  [{'id': 41, 'name': 'Activities', 'slug': 'per...
#
#                                    deal_id  \
# 0     0196edc7-e6a8-00c8-6ff5-ea60fa3f2895
# 12    01985615-068a-00c8-502e-689ad4f46f4f
# 52    019689e4-3a57-00c8-7868-45557942d2d8
# 130   0197f38c-7b86-00c8-5f68-b04a6261f5fb
# 192   0197110f-b551-00c8-bb33-cc3e6cb9e35d
# ...                                    ...
# 4325  01987abe-ce4d-00c8-ce82-dafcfa794b38
# 4345  01982c75-c255-00c8-ea44-eae4c5f1b2c7
# 4412  0198d0d3-612e-00c8-7f13-b352e4d24f27
# 4674  0197f874-bd80-00c8-d3c1-eb615d28429b
# 4921  019689e1-e244-00c8-e168-433ea084d2f5
#
#                                              main_image  \
# 0     uploads/deals/0196edc7-5969-ffff-6700-7ae699b8...
# 12    uploads/deals/01985615-0778-ffff-5f39-475ebacc...
# 52    uploads/deals/019689e4-3af8-ffff-5d5b-d3e82ea9...
# 130   uploads/deals/0197f38e-0f5c-ffff-d415-284934d8...
# 192   uploads/deals/0197110e-b95f-ffff-d561-18611b4a...
# ...                                                 ...
# 4325  uploads/deals/01987abe-cec7-ffff-5cef-0d4e8b68...
# 4345  uploads/deals/01982c6f-e76d-ffff-8407-b576b39a...
# 4412  uploads/deals/0198d0d3-61a2-ffff-f642-96a6c3c1...
# 4674  uploads/deals/0197f866-4cd4-ffff-919e-e4991862...
# 4921  uploads/deals/019689e1-e31c-ffff-e917-d6ebff37...
#
#       min_social_media_followers deal_tags                 live_since  \
# 0                           2500      None 2025-05-20 15:21:28.249567
# 12                          1500      None                        NaT
# 52                          2500      None                        NaT
# 130                         2500      None 2025-07-10 08:55:59.711606
# 192                         2500      None 2025-05-27 09:25:31.782749
# ...                          ...       ...                        ...
# 4325                        2500      None 2025-08-05 14:59:55.828209
# 4345                        2500      None 2025-07-21 10:09:31.872188
# 4412                        2500      None 2025-08-22 08:10:00.315465
# 4674                        2500      None 2025-07-11 07:48:09.918566
# 4921                        5000      None 2025-02-21 10:17:54.475290
#
#                      created_at                 updated_at  \
# 0    2025-05-20 13:00:23.080212 2025-10-28 10:55:34.719187
# 12   2025-07-29 12:07:55.274571 2025-07-29 12:08:05.638372
# 52   2023-10-17 16:28:45.927833 2025-05-01 03:29:18.311782
# 130  2025-07-10 08:55:59.622417 2025-08-04 13:36:29.925546
# 192  2025-05-27 09:25:31.601943 2025-10-28 10:49:53.144061
# ...                         ...                        ...
# 4325 2025-08-05 14:59:41.773835 2025-10-28 10:55:37.013826
# 4345 2025-07-21 10:09:31.733940 2025-07-21 10:09:31.872261
# 4412 2025-08-22 08:09:30.670778 2025-10-28 10:50:27.950474
# 4674 2025-07-11 07:48:09.728658 2025-10-28 11:03:58.435879
# 4921 2025-02-21 10:17:54.475290 2025-10-28 10:55:36.801519
#
#                            deleted_at  ...  tags  gender featured_image  \
# 0                                 NaT  ...  None    None           None
# 12                                NaT  ...  None    None           None
# 52   2024-05-31 08:26:35.053459+00:00  ...  None    None           None
# 130                               NaT  ...  None    None           None
# 192                               NaT  ...  None    None           None
# ...                               ...  ...   ...     ...            ...
# 4325                              NaT  ...  None    None           None
# 4345                              NaT  ...  None    None           None
# 4412                              NaT  ...  None    None           None
# 4674                              NaT  ...  None    None           None
# 4921                              NaT  ...  None    None           None
#
#                                 company_id test_nr_of_apps update_at_date  \
# 0     0199f1d4-b501-015e-5c45-1bc8300b3949              39     2025-10-28
# 12                                    None               0     2025-07-29
# 52                                    None               0     2025-05-01
# 130                                   None              27     2025-08-04
# 192   0199f1a1-0907-015e-1fc9-9934663110e1               5     2025-10-28
# ...                                    ...             ...            ...
# 4325  0199f1d4-b501-015e-5c45-1bc8300b3949              43     2025-10-28
# 4345                                  None             109     2025-07-21
# 4412  0199f1a5-e7d8-015e-73f9-509bb6bef028               6     2025-10-28
# 4674  0199f189-390d-015e-a393-817d2f4f3640              18     2025-10-28
# 4921  0199f1d4-b501-015e-5c45-1bc8300b3949              34     2025-10-28
#
#      diff  apps_after_7_days apps_after_7_days_OLD token_count
# 0       0                 39                  39.0         107
# 12      0                  0                   NaN           3
# 52      0                  0                   NaN          32
# 130     0                 24                  24.0         133
# 192     0                  5                   5.0         144
# ...   ...                ...                   ...         ...
# 4325    0                 21                  18.0          42
# 4345    0                 71                  49.0          99
# 4412    0                  5                   4.0          43
# 4674    0                 16                  14.0         131
# 4921    0                 34                   1.0          48
#
# [80 rows x 41 columns]

# %% [markdown]
# # Comparison
